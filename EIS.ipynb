# %% [markdown]
# Here is the plot of **Impedance** vs. **Frequency** for the *RLC* circuit:
#
# > Add blockquote
#
#
#
# The x-axis represents the *frequency* in Hertz (Hz) on a logarithmic scale.
# The y-axis represents the magnitude of the *impedance* in Ohms, also on a logarithmic scale.

# %% [markdown]
# ## RLC circuits

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
R = 100  # ohms
L = 1e-3  # henrys
C = 1e-6  # farads
frequencies = np.logspace(1, 6, 1000)
omega = 2 * np.pi * frequencies

# Impedance calculation
Z_R = R
Z_L = 1j * omega * L
Z_C = 1 / (1j * omega * C)
Z_RLC = Z_R + Z_L + Z_C

# Bode plot (Impedance vs Frequency)
plt.figure(figsize=(10, 6))
plt.loglog(frequencies, np.abs(Z_RLC), label='Magnitude')
plt.xlabel('ang. Frequency (Hz)')
plt.ylabel('Magnitude of Impedance (Ohms)')
plt.title('Impedance vs Frequency for RLC Circuit')
plt.grid(True, which="both", ls="--")
plt.legend()
plt.show()

# %%
# Parameters
R = 100  # ohms
L = 1e-3  # henrys
C = 1e-6  # farads
frequencies_l = np.linspace(1, 6, 1000)
omega = 2 * np.pi * frequencies_l   # 2pif

# Impedance calculation
Z_R = R
Z_2R = 200*R

Z_L = 1j * omega * L
Z_C = 1 / (1j * omega * C)
Z_RLC = Z_R + Z_L + Z_C



# Linear
# Bode plot (Impedance vs Frequency)
plt.figure(figsize=(10, 6))
plt.loglog(frequencies_l, np.abs(Z_RLC), label='Magnitude')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude of Impedance (Ohms)')
plt.title('Impedance vs Frequency for RLC Circuit')
plt.grid(True, which="both", ls="--")
plt.legend()
plt.show()

# %% [markdown]
# effect of individual elements
#
#
# R => 200xR
#
# L => 200L
#
# C ==> 200C

# %%
# Impedance calculation

# 200 times larger R
Z_2R = 200*R
Z_2RLC = Z_2R + Z_L + Z_C

Z_2L = 1j * omega *(200* L)
Z_2C = 1 / (1j * omega *(200*C))
Z_R2LC = Z_R + Z_2L + Z_C
Z_RL2C = Z_R + Z_L + Z_2C



# Linear
# Bode plot (Impedance vs Frequency)
plt.figure(figsize=(10, 6))
plt.loglog(frequencies_l, np.abs(Z_RLC), label='R')
plt.loglog(frequencies_l, np.abs(Z_2RLC), label='x200 R')
plt.loglog(frequencies_l, np.abs(Z_R2LC), label='x200 L')
#plt.loglog(frequencies_l, np.abs(Z_RL2C), label='x200 C')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude of Impedance (Ohms)')
plt.title('Impedance vs Frequency for RLC: x200R')
plt.grid(True, which="both", ls="--")
plt.legend()
plt.show()

# %%
# Create 4 subplots in a 2x2 grid
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# First subplot
axs[0, 0].loglog(frequencies_l, np.abs(Z_RLC), label='R')
axs[0, 0].loglog(frequencies_l, np.abs(Z_2RLC), label='x200 R')
axs[0, 0].set_xlabel('Frequency (Hz)')
axs[0, 0].set_ylabel('Magnitude of Impedance (Ohms)')
axs[0, 0].set_title('Impedance vs Frequency: R and x200 R')
axs[0, 0].grid(True, which="both", ls="--")
axs[0, 0].legend()

# Second subplot
axs[0, 1].loglog(frequencies_l, np.abs(Z_RLC), label='R')
axs[0, 1].loglog(frequencies_l, np.abs(Z_R2LC), label='x200 L')
axs[0, 1].set_xlabel('Frequency (Hz)')
axs[0, 1].set_ylabel('Magnitude of Impedance (Ohms)')
axs[0, 1].set_title('Impedance vs Frequency: R and x200 L')
axs[0, 1].grid(True, which="both", ls="--")
axs[0, 1].legend()

# Third subplot
axs[1, 0].loglog(frequencies_l, np.abs(Z_RLC), label='R')
axs[1, 0].loglog(frequencies_l, np.abs(Z_RL2C), label='x200 C')
axs[1, 0].set_xlabel('Frequency (Hz)')
axs[1, 0].set_ylabel('Magnitude of Impedance (Ohms)')
axs[1, 0].set_title('Impedance vs Frequency: R and x200 C')
axs[1, 0].grid(True, which="both", ls="--")
axs[1, 0].legend()

# Fourth subplot (all together)
axs[1, 1].loglog(frequencies_l, np.abs(Z_RLC), label='R')
axs[1, 1].loglog(frequencies_l, np.abs(Z_2RLC), label='x200 R')
axs[1, 1].loglog(frequencies_l, np.abs(Z_R2LC), label='x200 L')
axs[1, 1].loglog(frequencies_l, np.abs(Z_RL2C), label='x200 C')
axs[1, 1].set_xlabel('Frequency (Hz)')
axs[1, 1].set_ylabel('Magnitude of Impedance (Ohms)')
axs[1, 1].set_title('Impedance vs Frequency: All Together')
axs[1, 1].grid(True, which="both", ls="--")
axs[1, 1].legend()

# Adjust layout to avoid overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# *   Larger R increase impendace at higher frequencues
# *   L has no effect on impedance
# *   larger C lower impendace

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for individual components and combinations
frequencies = np.logspace(1, 6, 1000)
omega = 2 * np.pi * frequencies

# Resistor only
R = 100  # ohms
Z_R = R * np.ones_like(frequencies)

# Inductor only
L = 1e-3  # henrys
Z_L = 1j * omega * L

# Capacitor only
C = 1e-6  # farads
Z_C = 1 / (1j * omega * C)

# RL series
Z_RL = Z_R + Z_L

# RC series
Z_RC = Z_R + Z_C

# LC series
Z_LC = Z_L + Z_C

# Plotting
plt.figure(figsize=(14, 10))

# Individual components
plt.subplot(3, 1, 1)
plt.loglog(frequencies, np.abs(Z_R), label='R (Resistor)')
plt.loglog(frequencies, np.abs(Z_L), label='L (Inductor)')
plt.loglog(frequencies, np.abs(Z_C), label='C (Capacitor)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Impedance (Ohms)')
plt.title('Impedance vs Frequency for Individual Components')
plt.legend()
plt.grid(True, which="both", ls="--")

# Combinations RL, RC
plt.subplot(3, 1, 2)
plt.loglog(frequencies, np.abs(Z_RL), label='RL (Resistor + Inductor)')
plt.loglog(frequencies, np.abs(Z_RC), label='RC (Resistor + Capacitor)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Impedance (Ohms)')
plt.title('Impedance vs Frequency for RL and RC Circuits')
plt.legend()
plt.grid(True, which="both", ls="--")

# Combination LC
plt.subplot(3, 1, 3)
plt.loglog(frequencies, np.abs(Z_LC), label='LC (Inductor + Capacitor)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Impedance (Ohms)')
plt.title('Impedance vs Frequency for LC Circuit')
plt.legend()
plt.grid(True, which="both", ls="--")

plt.tight_layout()
plt.show()

# %%
# LC series
Z_RLC = Z_L + Z_C + Z_R


# Combination RLC
#plt.subplot(3, 1, 3)
plt.loglog(frequencies, np.abs(Z_RLC), label='RLC')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Impedance (Ohms)')
plt.title('Impedance vs Frequency for RLC Circuit')
plt.legend()
plt.grid(True, which="both", ls="--")

plt.tight_layout()
plt.show()

# %%
# Parameters for individual components and combinations
frequencies = np.linspace(1, 6, 1000)
omega = 2 * np.pi * frequencies

# Resistor only
R = 100  # ohms
Z_R = R * np.ones_like(frequencies)

# Inductor only
L = 1e-3  # henrys
Z_L = 1j * omega * L

# Capacitor only
C = 1e-6  # farads
Z_C = 1 / (1j * omega * C)

# RL series
Z_RL = Z_R + Z_L

# RC series
Z_RC = Z_R + Z_C

# LC series
Z_LC = Z_L + Z_C

# Plotting
plt.figure(figsize=(14, 10))

# Individual components
plt.subplot(3, 1, 1)
#plt.loglog(frequencies, np.abs(Z_R), label='R (Resistor)')
#plt.loglog(frequencies, np.abs(Z_L), label='L (Inductor)')
plt.loglog(frequencies, np.abs(Z_C), label='C (Capacitor)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Impedance (Ohms)')
plt.title('Impedance vs Frequency for Individual Components')
plt.legend()
plt.grid(True, which="both", ls="--")

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the parallel RC and series R2 circuit
frequencies = np.logspace(1, 6, 1000)
omega = 2 * np.pi * frequencies
R1 = 100  # ohms
R2 = 100  # ohms
C = 1e-6  # farads

# Impedance calculation for R1 and C in parallel
Z_R1 = R1 * np.ones_like(frequencies)
Z_C = 1 / (1j * omega * C)
Z_parallel_RC = 1 / (1 / Z_R1 + 1 / Z_C)

# Total impedance for (R1||C) in series with R2
Z_total = Z_parallel_RC + R2

# Plotting
plt.figure(figsize=(10, 6))
plt.loglog(frequencies, np.abs(Z_total), label='(R1||C) + R2')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Impedance (Ohms)')
plt.title('Impedance vs Frequency for (R1||C) + R2 Circuit')
plt.grid(True, which="both", ls="--")
plt.legend()
plt.show()

# %%
# Phase calculation for (R1||C) in series with R2
phase_total = np.angle(Z_total, deg=True)

# Plotting
plt.figure(figsize=(10, 6))
plt.semilogx(frequencies, phase_total, label='(R1||C) + R2')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Phase (Degrees)')
plt.title('Phase vs Frequency for (R1||C) + R2 Circuit')
plt.grid(True, which="both", ls="--")
plt.legend()
plt.show()

# %% [markdown]
# ## Nyquist plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the parallel RC and series R2 circuit
frequencies = np.logspace(1, 6, 1000)
omega = 2 * np.pi * frequencies
R1 = 200  # ohms
R2 = 20  # ohms
C = 1e-6  # farads

# Impedance calculation for R1 and C in parallel
Z_R1 = R1 * np.ones_like(frequencies)
Z_C = 1 / (1j * omega * C)
Z_parallel_RC = 1 / (1 / Z_R1 + 1 / Z_C)

# Total impedance for (R1||C) in series with R2
Z_total = Z_parallel_RC + R2

# Extracting real and imaginary parts
Z_real_total = Z_total.real
Z_imag_total = Z_total.imag

# Plotting Z(imaginary) vs Z(real)
plt.figure(figsize=(10, 8))

plt.plot(Z_real_total, -Z_imag_total, label='Total Impedance Trajectory')
plt.title('Imaginary vs Real Part of Total Impedance (Z)')
plt.xlabel('Z (Real Part)')
plt.ylabel('- Z (Imaginary Part)')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.show()

# %% [markdown]
# ## Bode PLot

# %%
# prompt: use var-s from above cell and make a bolde plot: log(|Z|) vs log(frequence) and on the same plot, with Y-axis on right:  Phase (Z) - vs log(frequece)

import matplotlib.pyplot as plt

# Assuming frequencies and Z_total are defined from the previous cell

fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot log(|Z|) vs log(frequency) on the left y-axis
color = 'tab:blue'
ax1.loglog(frequencies, np.abs(Z_total), color=color, label='log(|Z|)')
ax1.set_xlabel('log(Frequency)')
ax1.set_ylabel('log(|Z|)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True, which="both", ls="--")

# Create a second y-axis for Phase(Z)
ax2 = ax1.twinx()
color = 'tab:red'
ax2.semilogx(frequencies, np.angle(Z_total, deg=True), color=color, label='Phase(Z)')
ax2.set_ylabel('Phase (Z)', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Combine legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='lower left')


plt.title('Bode plot: log(|Z|) vs log(Frequency) and Phase(Z) vs log(Frequency)')
fig.tight_layout()
plt.show()

# %%
# prompt: creat plot with 2 sublot: 1st half nyqest plot and bode plot

import matplotlib.pyplot as plt

# Assuming frequencies, Z_total, Z_real_total, and Z_imag_total are defined from the previous code

fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Nyquist Plot
axs[0].plot(Z_real_total, -Z_imag_total, label='Total Impedance Trajectory')
axs[0].set_title('Nyquist Plot')
axs[0].set_xlabel('Real(Z)')
axs[0].set_ylabel('-Imag(Z)')
axs[0].grid(True)
axs[0].axhline(0, color='black', linewidth=0.5)
axs[0].axvline(0, color='black', linewidth=0.5)
axs[0].legend()

# Bode Plot
ax1 = axs[1]
color = 'tab:blue'
ax1.loglog(frequencies, np.abs(Z_total), color=color, label='log(|Z|)')
ax1.set_xlabel('log(Frequency)')
ax1.set_ylabel('log(|Z|)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True, which="both", ls="--")

ax2 = ax1.twinx()
color = 'tab:red'
ax2.semilogx(frequencies, np.angle(Z_total, deg=True), color=color, label='Phase(Z)')
ax2.set_ylabel('Phase (Z)', color=color)
ax2.tick_params(axis='y', labelcolor=color)

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='lower left')

axs[1].set_title('Bode Plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# Very Large C

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the parallel RC and series R2 circuit
frequencies = np.logspace(1, 6, 1000)
omega = 2 * np.pi * frequencies
R1 = 200  # ohms
R2 = 20  # ohms
C = 1e-6  # farads
C2 = C*100

# Impedance calculation for R1 and C in parallel
Z_R1 = R1 * np.ones_like(frequencies)
Z_C = 1 / (1j * omega * C)
Z_C2 = 1 / (1j * omega * C2)

Z_parallel_RC = 1 / (1 / Z_R1 + 1 / Z_C)
Z_parallel_RC2 = 1 / (1 / Z_R1 + 1 / Z_C2)

# Total impedance for (R1||C) in series with R2
Z_total = Z_parallel_RC + R2
Z_total2 = Z_parallel_RC2 + R2

# Extracting real and imaginary parts
Z_real_total = Z_total.real
Z_imag_total = Z_total.imag

Z_real_total2 = Z_total2.real
Z_imag_total2 = Z_total2.imag

# Plotting Z(imaginary) vs Z(real)
plt.figure(figsize=(10, 8))

plt.plot(Z_real_total, -Z_imag_total, label='Total Impedance Trajectory')
plt.plot(Z_real_total2, -Z_imag_total2, label='100 higher C')
plt.title('Imaginary vs Real Part of Total Impedance (Z)')
plt.xlabel('Z (Real Part)')
plt.ylabel('- Z (Imaginary Part)')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.show()

# %%
# prompt: also here, creade subplot: nyquies and bode plots. use parametes from the upper cell

import numpy as np
import matplotlib.pyplot as plt

# Assuming frequencies, Z_total, Z_real_total, and Z_imag_total are defined from the previous code

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Nyquist Plot
axs[0].plot(Z_real_total, -Z_imag_total, label='Total Impedance Trajectory')
axs[0].plot(Z_real_total2, -Z_imag_total2, label='100 higher C')
axs[0].set_title('Nyquist Plot')
axs[0].set_xlabel('Real(Z)')
axs[0].set_ylabel('-Imag(Z)')
axs[0].grid(True)
axs[0].axhline(0, color='black', linewidth=0.5)
axs[0].axvline(0, color='black', linewidth=0.5)
axs[0].legend()

# Bode Plot
ax1 = axs[1]
color = 'tab:blue'
ax1.loglog(frequencies, np.abs(Z_total), color=color, label='log(|Z|)')
ax1.loglog(frequencies, np.abs(Z_total2), color='black', label='log(|Z|) high C')
ax1.set_xlabel('log(Frequency)')
ax1.set_ylabel('log(|Z|)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True, which="both", ls="--")

ax2 = ax1.twinx()
color = 'tab:red'
ax2.semilogx(frequencies, np.angle(Z_total, deg=True), color=color, label='Phase(Z)')
ax2.semilogx(frequencies, np.angle(Z_total2, deg=True), color='purple', label='Phase(Z) High C')
ax2.set_ylabel('Phase (Z)', color=color)
ax2.tick_params(axis='y', labelcolor=color)

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='center right')

axs[1].set_title('Bode Plot')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the parallel RC and series R2 circuit
frequencies = np.logspace(1, 6, 1000)
omega = 2 * np.pi * frequencies
R1 = 200  # ohms
R2 = 20  # ohms
C = 1e-6  # farads
C2 = C*100
R3 = R2*10   # shifts starting point to right


R1b = R1*10



# Impedance calculation for R1 and C in parallel
Z_R1 = R1 * np.ones_like(frequencies)
Z_R1b = R1b * np.ones_like(frequencies)

Z_C = 1 / (1j * omega * C)
Z_C2 = 1 / (1j * omega * C2)

Z_parallel_RC = 1 / (1 / Z_R1 + 1 / Z_C)
Z_parallel_R1bC=1/(1 / Z_R1b + 1 / Z_C)
Z_parallel_RC2 = 1 / (1 / Z_R1 + 1 / Z_C2)


# Total impedance for (R1||C) in series with R2
Z_total = Z_parallel_RC + R2
Z_total2 = Z_parallel_RC2 + R2
Z_total3 = Z_parallel_RC2 + R3
Z_totalR1b=Z_parallel_R1bC+R2

# Extracting real and imaginary parts
Z_real_total = Z_total.real
Z_imag_total = Z_total.imag

Z_real_total2 = Z_total2.real
Z_imag_total2 = Z_total2.imag

Z_real_total3 = Z_total3.real
Z_imag_total3 = Z_total3.imag

Z_real_totalR1b = Z_totalR1b.real
Z_imag_totalR1b = Z_totalR1b.imag

# Plotting Z(imaginary) vs Z(real)
plt.figure(figsize=(10, 8))

plt.plot(Z_real_total, -Z_imag_total, label='Total Impedance Trajectory')
#plt.plot(Z_real_total2, -Z_imag_total2, label='Total Impedance Trajectory 2')
#plt.plot(Z_real_total3, -Z_imag_total3, label='Total Impedance Trajectory 3')
plt.plot(Z_real_totalR1b, -Z_imag_totalR1b, label='Total Impedance Trajectory R1b')
plt.title('Imaginary vs Real Part of Total Impedance (Z)')
plt.xlabel('Z (Real Part)')
plt.ylabel('- Z (Imaginary Part)')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.show()

# %%
# prompt: create subplot: nyquies and bode plots. use parametes from the upper cell

import matplotlib.pyplot as plt

# Assuming frequencies, Z_total, Z_real_total, and Z_imag_total are defined from the previous code

fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Nyquist Plot
axs[0].plot(Z_real_total, -Z_imag_total, label='Total Impedance Trajectory')
axs[0].plot(Z_real_total2, -Z_imag_total2, label='100 higher C')
#axs[0].plot(Z_real_total3, -Z_imag_total3, label='10 higher R2')
axs[0].plot(Z_real_totalR1b, -Z_imag_totalR1b, label='10 higher R1')
axs[0].set_title('Nyquist Plot')
axs[0].set_xlabel('Real(Z)')
axs[0].set_ylabel('-Imag(Z)')
axs[0].grid(True)
axs[0].axhline(0, color='black', linewidth=0.5)
axs[0].axvline(0, color='black', linewidth=0.5)
axs[0].legend()

# Bode Plot
ax1 = axs[1]
color = 'tab:blue'
ax1.loglog(frequencies, np.abs(Z_total), color=color, label='log(|Z|)')
ax1.loglog(frequencies, np.abs(Z_total2), color='black', label='log(|Z|) high C')
#ax1.loglog(frequencies, np.abs(Z_total3), color='green', label='log(|Z|) high R2')
ax1.loglog(frequencies, np.abs(Z_totalR1b), color='orange', label='log(|Z|) high R1')
ax1.set_xlabel('log(Frequency)')
ax1.set_ylabel('log(|Z|)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True, which="both", ls="--")

ax2 = ax1.twinx()
color = 'tab:red'
ax2.semilogx(frequencies, np.angle(Z_total, deg=True), color=color, label='Phase(Z)')
ax2.semilogx(frequencies, np.angle(Z_total2, deg=True), color='purple', label='Phase(Z) High C')
#ax2.semilogx(frequencies, np.angle(Z_total3, deg=True), color='brown', label='Phase(Z) high R2')
ax2.semilogx(frequencies, np.angle(Z_totalR1b, deg=True), color='pink', label='Phase(Z) high R1')

ax2.set_ylabel('Phase (Z)', color=color)
ax2.tick_params(axis='y', labelcolor=color)

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='center right')

axs[1].set_title('Bode Plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## add Warburg element

# %%
# Adding Warburg element
# Constants for Warburg element
w = 1000
pi_over_4 = np.pi / 4

# Warburg impedance calculations
Z_Warburg_magnitude = w / np.sqrt(frequencies)
Z_Warburg_phase = -pi_over_4 * np.ones_like(frequencies)
Z_Warburg = Z_Warburg_magnitude * (np.cos(Z_Warburg_phase) + 1j * np.sin(Z_Warburg_phase))

# Total impedance including Warburg element
Z_total_with_Warburg = Z_total + Z_Warburg

# Extracting real and imaginary parts
Z_real_total = Z_total.real
Z_imag_total = Z_total.imag

Z_real_total_with_Warburg = Z_total_with_Warburg.real
Z_imag_total_with_Warburg = Z_total_with_Warburg.imag

# Plotting Z(imaginary) vs Z(real)
plt.figure(figsize=(10, 8))

plt.plot(Z_real_total, -Z_imag_total, label='Total Impedance Trajectory')
plt.plot(Z_real_total_with_Warburg, -Z_imag_total_with_Warburg, label='Total Impedance with Warburg', linestyle='--')
plt.title('Imaginary vs Real Part of Total Impedance (Z)')
plt.xlabel('Z (Real Part)')
plt.ylabel('- Z (Imaginary Part)')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.show()

# %%
# Recalculate Z_Warburg correctly
# Warburg impedance has a real and imaginary part both influenced by the sqrt(frequency)
Z_Warburg = Z_Warburg_magnitude * (np.cos(Z_Warburg_phase) + 1j * np.sin(Z_Warburg_phase))

# Total impedance including Warburg element
Z_total_with_Warburg = Z_parallel_RC + R2 + Z_Warburg

# Extracting real and imaginary parts
Z_real_total_with_Warburg = Z_total_with_Warburg.real
Z_imag_total_with_Warburg = Z_total_with_Warburg.imag

# Plotting Z(imaginary) vs Z(real)
plt.figure(figsize=(10, 8))

plt.plot(Z_real_total, -Z_imag_total, label='Total Impedance Trajectory')
plt.plot(Z_real_total_with_Warburg, -Z_imag_total_with_Warburg, label='Total Impedance with Warburg', linestyle='--')
plt.title('Imaginary vs Real Part of Total Impedance (Z)')
plt.xlabel('Z (Real Part)')
plt.ylabel('- Z (Imaginary Part)')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.show()

# %% [markdown]
# ## L+p(R-C)

# %%
# Parameters for the parallel RC and series R2 circuit
frequencies = np.logspace(1, 6, 1000)
omega = 2 * np.pi * frequencies
R1 = 200  # ohms
R2 = 20  # ohms
C = 1e-6  # farads
L = 100  #e-3  # henrys



# Impedance calculation for R1 and C in parallel
Z_R1 = R1 * np.ones_like(frequencies)
Z_C = 1 / (1j * omega * C)
Z_parallel_RC = 1 / (1 / Z_R1 + 1 / Z_C)

# Total impedance for (R1||C) in series with R2
Z_total = Z_parallel_RC + R2

# Total impedance for (R1||C) in series with L
Z_total_L = Z_parallel_RC + L

# Extracting real and imaginary parts
Z_real_total = Z_total.real
Z_imag_total = Z_total.imag


# Extracting real and imaginary parts
Z_real_total_L = Z_total_L.real
Z_imag_total_L = Z_total_L.imag

# Plotting Z(imaginary) vs Z(real)
plt.figure(figsize=(10, 8))

plt.plot(Z_real_total, -Z_imag_total, label='R + p(R||C)')
plt.plot(Z_real_total_L, -Z_imag_total_L, label='L + p(R||C)')
plt.title('Imaginary vs Real Part of Total Impedance (Z)')
plt.xlabel('Z (Real Part)')
plt.ylabel('- Z (Imaginary Part)')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.show()

# %%
# prompt: plot nyquist plot and bode plot for L-R circuit
# make two curves:
# 1) L = 100, R = 100
# 2) L = 500, R = 100

import numpy as np
import matplotlib.pyplot as plt

# Define frequencies
frequencies = np.logspace(0, 5, 500)  # Adjust frequency range as needed
omega = 2 * np.pi * frequencies

# Function to calculate impedance for LR circuit
def impedance_LR(R, L, omega):
  return R + 1j * omega * L

# Parameters for the two curves
L1, R1 = 100, 100
L2, R2 = 10000, 100

# Calculate impedances
Z1 = impedance_LR(R1, L1, omega)
Z2 = impedance_LR(R2, L2, omega)


# --- Nyquist Plots ---
plt.figure(figsize=(8, 6))
plt.plot(Z1.real, -Z1.imag, label=f'L={L1}, R={R1}')
plt.plot(Z2.real, -Z2.imag, label=f'L={L2}, R={R2}')
plt.xlabel('Real(Z)')
plt.ylabel('-Imag(Z)')
plt.title('Nyquist Plot for LR Circuit')
plt.grid(True)
plt.legend()
plt.show()


# --- Bode Plots ---
fig, axs = plt.subplots(2, 1, figsize=(8, 8))

# Magnitude plot
axs[0].loglog(frequencies, np.abs(Z1), label=f'L={L1}, R={R1}')
axs[0].loglog(frequencies, np.abs(Z2), label=f'L={L2}, R={R2}')
axs[0].set_xlabel('Frequency (Hz)')
axs[0].set_ylabel('Magnitude (Ohms)')
axs[0].set_title('Bode Plot (Magnitude)')
axs[0].grid(True)
axs[0].legend()


# Phase plot
axs[1].semilogx(frequencies, np.angle(Z1, deg=True), label=f'L={L1}, R={R1}')
axs[1].semilogx(frequencies, np.angle(Z2, deg=True), label=f'L={L2}, R={R2}')
axs[1].set_xlabel('Frequency (Hz)')
axs[1].set_ylabel('Phase (degrees)')
axs[1].set_title('Bode Plot (Phase)')
axs[1].grid(True)
axs[1].legend()


plt.tight_layout()
plt.show()

# %%
# prompt: plot 2: L-R-C :  1) L= 100, R =100, C = 1 pF    2)  L= 100, R =100, C = 0.1 F

import numpy as np
import matplotlib.pyplot as plt

# Define frequencies
frequencies = np.logspace(0, 5, 500)  # Adjust frequency range as needed
omega = 2 * np.pi * frequencies

# Function to calculate impedance for LRC circuit
def impedance_LRC(R, L, C, omega):
    Z_L = 1j * omega * L
    Z_C = 1 / (1j * omega * C)
    Z_R = R
    return Z_R + Z_L + Z_C

# Parameters for the two curves
L1, R1, C1 = 100, 100, 1e-16  # 1 pF
L2, R2, C2 = 1, 100, 1e-6     # 0.1 F

# Calculate impedances
Z1 = impedance_LRC(R1, L1, C1, omega)
Z2 = impedance_LRC(R2, L2, C2, omega)


# --- Nyquist Plots ---
plt.figure(figsize=(8, 6))
plt.plot(Z1.real, -Z1.imag, label=f'L={L1}, R={R1}, C={C1} F')
plt.plot(Z2.real, -Z2.imag, label=f'L={L2}, R={R2}, C={C2} F')
plt.xlabel('Real(Z)')
plt.ylabel('-Imag(Z)')
plt.title('Nyquist Plot for LRC Circuit')
plt.grid(True)
plt.legend()
plt.show()


# --- Bode Plots ---
fig, axs = plt.subplots(2, 1, figsize=(8, 8))

# Magnitude plot
axs[0].loglog(frequencies, np.abs(Z1), label=f'L={L1}, R={R1}, C={C1} F')
axs[0].loglog(frequencies, np.abs(Z2), label=f'L={L2}, R={R2}, C={C2} F')
axs[0].set_xlabel('Frequency (Hz)')
axs[0].set_ylabel('Magnitude (Ohms)')
axs[0].set_title('Bode Plot (Magnitude)')
axs[0].grid(True)
axs[0].legend()


# Phase plot
axs[1].semilogx(frequencies, np.angle(Z1, deg=True), label=f'L={L1}, R={R1}, C={C1} F')
axs[1].semilogx(frequencies, np.angle(Z2, deg=True), label=f'L={L2}, R={R2}, C={C2} F')
axs[1].set_xlabel('Frequency (Hz)')
axs[1].set_ylabel('Phase (degrees)')
axs[1].set_title('Bode Plot (Phase)')
axs[1].grid(True)
axs[1].legend()


plt.tight_layout()
plt.show()

# %%
# prompt: ValueError: x and y must have same first dimension, but have shapes (500,) and (1000,)

# Define frequencies
frequencies = np.logspace(0, 5, 1000)  # Use 1000 frequencies to match Z_total's shape
omega = 2 * np.pi * frequencies

# Function to calculate impedance for LR circuit
def impedance_LR(R, L, omega):
  return R + 1j * omega * L

# Parameters for the two curves
L1, R1 = 100, 100
L2, R2 = 10000, 100

# Calculate impedances
Z1 = impedance_LR(R1, L1, omega)
Z2 = impedance_LR(R2, L2, omega)


# --- Nyquist Plots ---
plt.figure(figsize=(8, 6))
plt.plot(Z1.real, -Z1.imag, label=f'L={L1}, R={R1}')
plt.plot(Z2.real, -Z2.imag, label=f'L={L2}, R={R2}')
plt.xlabel('Real(Z)')
plt.ylabel('-Imag(Z)')
plt.title('Nyquist Plot for LR Circuit')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # (R||C)-(R||C)

# %%
# Parameters for the parallel RC and series R2 circuit
frequencies = np.logspace(1, 6, 1000)
omega = 2 * np.pi * frequencies
R1 = 10000  # ohms
R2 = 100000  # ohms

R2b = R2

C = 1e-9  # farads
C2 = 1e-8  # arads
C2b = C2*100



# Impedance calculation for R1 and C in parallel
Z_R1 = R1 * np.ones_like(frequencies)
Z_R2 = R2 * np.ones_like(frequencies)
Z_R2b = R2b * np.ones_like(frequencies)

Z_C = 1 / (1j * omega * C)
Z_C2 = 1 / (1j * omega * C2)
Z_C2b = 1 / (1j * omega * C2b)


Z_parallel_RC = 1 / (1 / Z_R1 + 1 / Z_C)
Z_parallel_RC2 = 1 / (1 / Z_R2 + 1 / Z_C2)
Z_parallel_RC2b = 1 / (1 / Z_R2b + 1 / Z_C2b)

# Total impedance for (R1||C)+(R2||C2)
Z_total = Z_parallel_RC + Z_parallel_RC2
Z_total2 = Z_parallel_RC + Z_parallel_RC2b



# Extracting real and imaginary parts
Z_real_total = Z_total.real
Z_imag_total = Z_total.imag

Z_real_total2 = Z_total2.real
Z_imag_total2 = Z_total2.imag



# Plotting Z(imaginary) vs Z(real)
plt.figure(figsize=(5, 5))

plt.plot(Z_real_total, -Z_imag_total, label='(R1||C)+(R2||C2)')
plt.plot(Z_real_total2, -Z_imag_total2, label='(R1||C)+(R2||C2b)')
#plt.title('Imaginary vs Real Part of Total Impedance (Z)')
plt.xlabel('Z (Real Part)')
plt.ylabel('- Z (Imaginary Part)')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.show()

# %%
# prompt: creat bode plots alse here

import numpy as np
import matplotlib.pyplot as plt



fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Nyquist Plot
axs[0].plot(Z_real_total, -Z_imag_total, label='(R1||C)+(R2||C2)')
#axs[0].plot(Z_real_total2, -Z_imag_total2, label='(R1||C)+(R2||C2b)')
#axs[0].set_title('Nyquist Plot')
axs[0].set_xlabel('Real(Z)')
axs[0].set_ylabel('-Imag(Z)')
axs[0].grid(True)
axs[0].axhline(0, color='black', linewidth=0.5)
axs[0].axvline(0, color='black', linewidth=0.5)
axs[0].legend()

# Bode Plot
ax1 = axs[1]
color = 'tab:blue'
#ax1.loglog(frequencies, np.abs(Z_total), color=color, label='log(|Z|)')
#ax1.loglog(frequencies, np.abs(Z_total2), color='black', label='log(|Z|) high C')
ax1.set_xlabel('log(Frequency)')
ax1.set_ylabel('log(|Z|)', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True, which="both", ls="--")

ax2 = ax1.twinx()
color = 'tab:red'
ax2.semilogx(frequencies, np.angle(Z_total, deg=True), color=color, label='Phase(Z)')
ax2.semilogx(frequencies, np.angle(Z_total2, deg=True), color='purple', label='Phase(Z) High C')
ax2.set_ylabel('Phase (Z)', color=color)
ax2.tick_params(axis='y', labelcolor=color)

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='center right')

#axs[1].set_title('Bode Plot')

plt.tight_layout()
plt.show()

# %%
# prompt: calculate capacitance of silica with  thikness of5 nm by formula: t =3.8*e*S/C
# where e is vacuum permeability and C is capacitance

import numpy as np

# Constants
t = 5e-9  # Thickness in meters (5 nm)
e = 8.854e-12  # Vacuum permittivity in F/m
S = 1e-6 # 1 mm2 Surface Area


# Calculate capacitance
C = 3.8 * e * S / t

print(f"The capacitance of the silica layer is: {C} F")
# Out:
# The capacitance of the silica layer is: 6.729039999999999e-09 F

# %%
# prompt: calculate thickness, if   C =7.7e-9 ( +/- 3e-10) F

# Constants
e = 8.854e-12  # Vacuum permittivity in F/m
S = 1e-6 # Surface Area
C = 7.7e-9  # Capacitance in Farads
C_uncertainty = 3e-10 # Uncertainty in capacitance

# Calculate thickness with uncertainty propagation
t = 3.8 * e * S / C
t_uncertainty = t * (C_uncertainty / C)

print(f"The thickness of the silica layer is: {t} m +/- {t_uncertainty} m")
# Out:
# The thickness of the silica layer is: 4.3695064935064935e-09 m +/- 1.7024051273401922e-10 m

# %%
# prompt: assume thikness of t=100 nm and calculate conducitivty with formula sigma=4*t/(S*R), where R = 1.21e7

# Constants
t = 400e-9  # Thickness in meters (100 nm)
R = 1.21e7  # Resistance in ohms
S = 1e-6  # Assuming a surface area of 1 mm^2 (adjust if needed)

# Calculate conductivity
sigma = (4 * t / (S * R))*100 #(ohm cm)

print(f"The conductivity is: {sigma} S/cm")
# Out:
# The conductivity is: 1.3223140495867768e-05 S/cm

# %%
# prompt: what will be log of sigma

import math

# Assuming sigma is defined from the previous code
log_sigma = math.log(sigma)
print(f"The log of sigma is: {log_sigma}")
# Out:
# The log of sigma is: -11.233542195333143

# %%
# prompt: what should be Resistance for 1000 nm YSZ film, to have conductivity  log(sigma) ~ -4 S/cm

# Constants
t = 1000e-9  # Thickness in meters (1000 nm)
S = 1e-6  # Assuming a surface area of 1 mm^2 (adjust if needed)
log_sigma = -4  # log(sigma)

# Calculate sigma
sigma = 10**log_sigma

# Calculate resistance
R = (4 * t) / (S * sigma*100)  # Convert conductivity to S/cm

print(f"The resistance should be: {R} ohms")
# Out:
# The resistance should be: 400.0 ohms
